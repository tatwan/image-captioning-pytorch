# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# Some of the
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
#
# I consulted the two papers listed above "Show and Tell: A Neural Image Caption Generator" and "Show, Attend and Tell: Neural Image Caption Generation with Visual Attention" to gain a better understanding on the overall process and framework to implement an Image Caption.
#
# The overall approach includes an Encoder and a Decoder. The **Encoder** leveraged a pre-trained CNN architecture like `ResNet-50` to help extract features from the images. The line `modules = list(resnet.children())[:-1]` is when we remove the last Fully Connected layer in the pre-trained architecture. The goal of the encoder is to enode the content of the image into a smaller feature vector. Which later gets passed to the Decoder (RNN) network.
#
# The **Decoder** which is our LSTM that we use to generate the captions for an image. We pass the encoder embedding as input to the LSTM to learn. The vocabulary in the trainnig pool are pretty much all the unique words in our data set, with the added <start> and <end> tokens to indicate start and end of a sentence.
#
# I used a `vecob_threshold` of 4. The number of words were better than 5, and I did not want to increase the vocab words to include every rare word that may have only been used once. A balance would be key, so I went with 4. If I would test and rerun the training again, I would like to try 2-3 to evaluate the generated captions and the quality of the output.
#
# for the `batch_size` I think 10 was too small. If I had the bandwitdh to rerun this again, I would probably increase this value and the size of each batch to maybe 32.
#
# `embed_size` is used both in embedded image feature vector and word embedding. In this case I used 256 and a `hidden_size` of 512.
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
# The `transform_train` was not changed. It covered resizing, random cropping, random horizontal flip, converting to tensor, followed by normalization. This is a standard image transformer that I felt was more than sufficient for the current task. These transformations are what is needed for the `ResNet50` since it is a pre-trained model we need to make sure the images are in the expected size and normal form.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
# For the trainable parameters I made all the weights int he decoder trainable, which at every iteration they get updated. For the encoder, I used to only updated the weights in the emedding layer.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**
# I selected Adam optimizer, instead of SGD. From past experiences I have seen it perform/converge faster. When I first started the training I used the wrong learning rate of 0.01 which was too high and there was no improvement and had to end it after 1 epoch. I updated the Learning Rate to 0.001 and noticed signifcant improvement in the overall learning.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## Select appropriate values for the Python variables below.
batch_size = 10          # batch size
vocab_threshold = 4        # minimum word count threshold
vocab_from_file = True      # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional)  Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# Specify the learnable parameters of the model.
params = list(decoder.parameters())+list(encoder.embed.parameters())

# Define the optimizer.
optimizer = torch.optim.Adam(params,lr=0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
#   0%|          | 0/414113 [00:00<?, ?it/s]
# Done (t=0.97s)
# creating index...
# index created!
# Obtaining caption lengths...
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-2-cc40512439d8> in <module>()
#      35                          batch_size=batch_size,
#      36                          vocab_threshold=vocab_threshold,
# ---> 37                          vocab_from_file=vocab_from_file)
#      38
#      39 # The size of the vocabulary.
#
# /home/workspace/data_loader.py in get_loader(transform, mode, batch_size, vocab_threshold, vocab_file, start_word, end_word, unk_word, vocab_from_file, num_workers, cocoapi_loc)
#      64                           annotations_file=annotations_file,
#      65                           vocab_from_file=vocab_from_file,
# ---> 66                           img_folder=img_folder)
#      67
#      68     if mode == 'train':
#
# /home/workspace/data_loader.py in __init__(self, transform, mode, batch_size, vocab_threshold, vocab_file, start_word, end_word, unk_word, annotations_file, vocab_from_file, img_folder)
#      99             self.ids = list(self.coco.anns.keys())
#     100             print('Obtaining caption lengths...')
# --> 101             all_tokens = [nltk.tokenize.word_tokenize(str(self.coco.anns[self.ids[index]]['caption']).lower()) for index in tqdm(np.arange(len(self.ids)))]
#     102             self.caption_lengths = [len(token) for token in all_tokens]
#     103         else:
#
# /home/workspace/data_loader.py in <listcomp>(.0)
#      99             self.ids = list(self.coco.anns.keys())
#     100             print('Obtaining caption lengths...')
# --> 101             all_tokens = [nltk.tokenize.word_tokenize(str(self.coco.anns[self.ids[index]]['caption']).lower()) for index in tqdm(np.arange(len(self.ids)))]
#     102             self.caption_lengths = [len(token) for token in all_tokens]
#     103         else:
#
# /opt/conda/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# /opt/conda/lib/python3.6/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      92     :param language: the model name in the Punkt corpus
#      93     """
# ---> 94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#      95     return tokenizer.tokenize(text)
#      96
#
# /opt/conda/lib/python3.6/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     832
#     833     # Load the resource.
# --> 834     opened_resource = _open(resource_url)
#     835
#     836     if format == 'raw':
#
# /opt/conda/lib/python3.6/site-packages/nltk/data.py in _open(resource_url)
#     950
#     951     if protocol is None or protocol.lower() == 'nltk':
# --> 952         return find(path_, path + ['']).open()
#     953     elif protocol.lower() == 'file':
#     954         # urllib might not use mode='rb', so handle this one ourselves:
#
# /opt/conda/lib/python3.6/site-packages/nltk/data.py in find(resource_name, paths)
#     671     sep = '*' * 70
#     672     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 673     raise LookupError(resource_not_found)
#     674
#     675
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - '/opt/conda/nltk_data'
#     - '/opt/conda/lib/nltk_data'
#     - ''
# **********************************************************************

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/41412], Loss: 3.9199, Perplexity: 50.3946
# Epoch [1/3], Step [200/41412], Loss: 3.8811, Perplexity: 48.47934
# Epoch [1/3], Step [300/41412], Loss: 4.1208, Perplexity: 61.60637
# Epoch [1/3], Step [400/41412], Loss: 4.0939, Perplexity: 59.9729
# Epoch [1/3], Step [500/41412], Loss: 3.5057, Perplexity: 33.3039
# Epoch [1/3], Step [600/41412], Loss: 2.7064, Perplexity: 14.97529
# Epoch [1/3], Step [700/41412], Loss: 3.3131, Perplexity: 27.4701
# Epoch [1/3], Step [800/41412], Loss: 3.8917, Perplexity: 48.9928
# Epoch [1/3], Step [900/41412], Loss: 3.7853, Perplexity: 44.0471
# Epoch [1/3], Step [1000/41412], Loss: 3.8163, Perplexity: 45.4354
# Epoch [1/3], Step [1100/41412], Loss: 3.6709, Perplexity: 39.2863
# Epoch [1/3], Step [1200/41412], Loss: 2.7893, Perplexity: 16.26888
# Epoch [1/3], Step [1300/41412], Loss: 3.2087, Perplexity: 24.7476
# Epoch [1/3], Step [1400/41412], Loss: 3.0189, Perplexity: 20.4686
# Epoch [1/3], Step [1500/41412], Loss: 3.1554, Perplexity: 23.4615
# Epoch [1/3], Step [1600/41412], Loss: 2.9931, Perplexity: 19.94726
# Epoch [1/3], Step [1700/41412], Loss: 3.4225, Perplexity: 30.6447
# Epoch [1/3], Step [1800/41412], Loss: 2.7767, Perplexity: 16.0661
# Epoch [1/3], Step [1900/41412], Loss: 3.1828, Perplexity: 24.1139
# Epoch [1/3], Step [2000/41412], Loss: 2.9757, Perplexity: 19.60359
# Epoch [1/3], Step [2100/41412], Loss: 3.2313, Perplexity: 25.3114
# Epoch [1/3], Step [2200/41412], Loss: 2.4955, Perplexity: 12.1280
# Epoch [1/3], Step [2300/41412], Loss: 2.8622, Perplexity: 17.49999
# Epoch [1/3], Step [2400/41412], Loss: 2.2266, Perplexity: 9.26869
# Epoch [1/3], Step [2500/41412], Loss: 3.4435, Perplexity: 31.2963
# Epoch [1/3], Step [2600/41412], Loss: 3.2455, Perplexity: 25.6744
# Epoch [1/3], Step [2700/41412], Loss: 3.3836, Perplexity: 29.4763
# Epoch [1/3], Step [2800/41412], Loss: 2.9011, Perplexity: 18.1946
# Epoch [1/3], Step [2900/41412], Loss: 3.2399, Perplexity: 25.5299
# Epoch [1/3], Step [3000/41412], Loss: 3.1494, Perplexity: 23.3232
# Epoch [1/3], Step [3100/41412], Loss: 2.9332, Perplexity: 18.7869
# Epoch [1/3], Step [3200/41412], Loss: 2.2986, Perplexity: 9.96079
# Epoch [1/3], Step [3300/41412], Loss: 2.5793, Perplexity: 13.1884
# Epoch [1/3], Step [3400/41412], Loss: 2.6363, Perplexity: 13.9615
# Epoch [1/3], Step [3500/41412], Loss: 2.6727, Perplexity: 14.4795
# Epoch [1/3], Step [3600/41412], Loss: 2.8565, Perplexity: 17.4011
# Epoch [1/3], Step [3700/41412], Loss: 2.9134, Perplexity: 18.4186
# Epoch [1/3], Step [3800/41412], Loss: 2.6178, Perplexity: 13.7054
# Epoch [1/3], Step [3900/41412], Loss: 3.1192, Perplexity: 22.6287
# Epoch [1/3], Step [4000/41412], Loss: 2.7974, Perplexity: 16.4019
# Epoch [1/3], Step [4100/41412], Loss: 2.7356, Perplexity: 15.4193
# Epoch [1/3], Step [4200/41412], Loss: 3.1649, Perplexity: 23.6858
# Epoch [1/3], Step [4300/41412], Loss: 2.4824, Perplexity: 11.9695
# Epoch [1/3], Step [4400/41412], Loss: 2.6866, Perplexity: 14.6810
# Epoch [1/3], Step [4500/41412], Loss: 2.6444, Perplexity: 14.0751
# Epoch [1/3], Step [4600/41412], Loss: 3.1777, Perplexity: 23.9924
# Epoch [1/3], Step [4700/41412], Loss: 2.8923, Perplexity: 18.0341
# Epoch [1/3], Step [4800/41412], Loss: 3.3647, Perplexity: 28.9237
# Epoch [1/3], Step [4900/41412], Loss: 2.3955, Perplexity: 10.9741
# Epoch [1/3], Step [5000/41412], Loss: 2.8478, Perplexity: 17.2503
# Epoch [1/3], Step [5100/41412], Loss: 2.4681, Perplexity: 11.8001
# Epoch [1/3], Step [5200/41412], Loss: 2.7490, Perplexity: 15.6274
# Epoch [1/3], Step [5300/41412], Loss: 3.1484, Perplexity: 23.2997
# Epoch [1/3], Step [5400/41412], Loss: 2.4896, Perplexity: 12.0563
# Epoch [1/3], Step [5500/41412], Loss: 3.0160, Perplexity: 20.4089
# Epoch [1/3], Step [5600/41412], Loss: 2.3868, Perplexity: 10.8785
# Epoch [1/3], Step [5700/41412], Loss: 3.1622, Perplexity: 23.6234
# Epoch [1/3], Step [5800/41412], Loss: 2.7864, Perplexity: 16.2218
# Epoch [1/3], Step [5900/41412], Loss: 2.4457, Perplexity: 11.5381
# Epoch [1/3], Step [6000/41412], Loss: 2.6030, Perplexity: 13.5039
# Epoch [1/3], Step [6100/41412], Loss: 2.3308, Perplexity: 10.2863
# Epoch [1/3], Step [6200/41412], Loss: 3.3969, Perplexity: 29.8702
# Epoch [1/3], Step [6300/41412], Loss: 3.2160, Perplexity: 24.9294
# Epoch [1/3], Step [6400/41412], Loss: 2.4133, Perplexity: 11.1707
# Epoch [1/3], Step [6500/41412], Loss: 2.5308, Perplexity: 12.5634
# Epoch [1/3], Step [6600/41412], Loss: 2.5562, Perplexity: 12.8872
# Epoch [1/3], Step [6700/41412], Loss: 2.1696, Perplexity: 8.75473
# Epoch [1/3], Step [6800/41412], Loss: 2.7558, Perplexity: 15.7335
# Epoch [1/3], Step [6900/41412], Loss: 2.4945, Perplexity: 12.1156
# Epoch [1/3], Step [7000/41412], Loss: 3.0957, Perplexity: 22.1016
# Epoch [1/3], Step [7100/41412], Loss: 2.4577, Perplexity: 11.6777
# Epoch [1/3], Step [7200/41412], Loss: 2.8061, Perplexity: 16.5453
# Epoch [1/3], Step [7300/41412], Loss: 3.0875, Perplexity: 21.9232
# Epoch [1/3], Step [7400/41412], Loss: 2.3938, Perplexity: 10.9552
# Epoch [1/3], Step [7500/41412], Loss: 3.4853, Perplexity: 32.6331
# Epoch [1/3], Step [7600/41412], Loss: 2.6398, Perplexity: 14.01085
# Epoch [1/3], Step [7700/41412], Loss: 2.9338, Perplexity: 18.7987
# Epoch [1/3], Step [7800/41412], Loss: 3.2143, Perplexity: 24.8849
# Epoch [1/3], Step [7900/41412], Loss: 2.7471, Perplexity: 15.5968
# Epoch [1/3], Step [8000/41412], Loss: 2.4259, Perplexity: 11.3126
# Epoch [1/3], Step [8100/41412], Loss: 2.7976, Perplexity: 16.4057
# Epoch [1/3], Step [8200/41412], Loss: 2.8623, Perplexity: 17.5018
# Epoch [1/3], Step [8300/41412], Loss: 3.0952, Perplexity: 22.0923
# Epoch [1/3], Step [8400/41412], Loss: 3.0604, Perplexity: 21.3351
# Epoch [1/3], Step [8500/41412], Loss: 2.2601, Perplexity: 9.58381
# Epoch [1/3], Step [8600/41412], Loss: 2.7913, Perplexity: 16.3017
# Epoch [1/3], Step [8700/41412], Loss: 2.9139, Perplexity: 18.42870
# Epoch [1/3], Step [8800/41412], Loss: 2.3652, Perplexity: 10.6461
# Epoch [1/3], Step [8900/41412], Loss: 2.9107, Perplexity: 18.3703
# Epoch [1/3], Step [9000/41412], Loss: 2.3844, Perplexity: 10.85267
# Epoch [1/3], Step [9100/41412], Loss: 2.5029, Perplexity: 12.2182
# Epoch [1/3], Step [9200/41412], Loss: 2.8844, Perplexity: 17.8922
# Epoch [1/3], Step [9300/41412], Loss: 2.3793, Perplexity: 10.7975
# Epoch [1/3], Step [9400/41412], Loss: 3.1882, Perplexity: 24.2438
# Epoch [1/3], Step [9500/41412], Loss: 2.9546, Perplexity: 19.1938
# Epoch [1/3], Step [9600/41412], Loss: 2.4772, Perplexity: 11.9073
# Epoch [1/3], Step [9700/41412], Loss: 2.5105, Perplexity: 12.3108
# Epoch [1/3], Step [9800/41412], Loss: 1.9221, Perplexity: 6.83552
# Epoch [1/3], Step [9900/41412], Loss: 2.7835, Perplexity: 16.1762
# Epoch [1/3], Step [10000/41412], Loss: 2.8588, Perplexity: 17.4402
# Epoch [1/3], Step [10100/41412], Loss: 2.9496, Perplexity: 19.0985
# Epoch [1/3], Step [10200/41412], Loss: 2.2028, Perplexity: 9.05058
# Epoch [1/3], Step [10300/41412], Loss: 2.3768, Perplexity: 10.7702
# Epoch [1/3], Step [10400/41412], Loss: 2.4839, Perplexity: 11.9884
# Epoch [1/3], Step [10500/41412], Loss: 2.8781, Perplexity: 17.7798
# Epoch [1/3], Step [10600/41412], Loss: 3.3192, Perplexity: 27.6389
# Epoch [1/3], Step [10700/41412], Loss: 2.1455, Perplexity: 8.54674
# Epoch [1/3], Step [10800/41412], Loss: 2.7069, Perplexity: 14.9827
# Epoch [1/3], Step [10900/41412], Loss: 2.6934, Perplexity: 14.7825
# Epoch [1/3], Step [11000/41412], Loss: 2.5459, Perplexity: 12.75473
# Epoch [1/3], Step [11100/41412], Loss: 2.5734, Perplexity: 13.1104
# Epoch [1/3], Step [11200/41412], Loss: 2.2552, Perplexity: 9.53752
# Epoch [1/3], Step [11300/41412], Loss: 2.7806, Perplexity: 16.1289
# Epoch [1/3], Step [11400/41412], Loss: 2.3523, Perplexity: 10.5095
# Epoch [1/3], Step [11500/41412], Loss: 2.6836, Perplexity: 14.6377
# Epoch [1/3], Step [11600/41412], Loss: 2.7053, Perplexity: 14.9588
# Epoch [1/3], Step [11700/41412], Loss: 2.4251, Perplexity: 11.3032
# Epoch [1/3], Step [11800/41412], Loss: 2.7121, Perplexity: 15.0606
# Epoch [1/3], Step [11900/41412], Loss: 3.2548, Perplexity: 25.9137
# Epoch [1/3], Step [12000/41412], Loss: 2.0918, Perplexity: 8.09959
# Epoch [1/3], Step [12100/41412], Loss: 2.7817, Perplexity: 16.1464
# Epoch [1/3], Step [12200/41412], Loss: 2.6392, Perplexity: 14.0018
# Epoch [1/3], Step [12300/41412], Loss: 2.1401, Perplexity: 8.50073
# Epoch [1/3], Step [12400/41412], Loss: 2.3085, Perplexity: 10.0590
# Epoch [1/3], Step [12500/41412], Loss: 2.1075, Perplexity: 8.22780
# Epoch [1/3], Step [12600/41412], Loss: 3.0853, Perplexity: 21.8739
# Epoch [1/3], Step [12700/41412], Loss: 2.5236, Perplexity: 12.4729
# Epoch [1/3], Step [12800/41412], Loss: 2.6318, Perplexity: 13.8987
# Epoch [1/3], Step [12900/41412], Loss: 3.3202, Perplexity: 27.6654
# Epoch [1/3], Step [13000/41412], Loss: 2.3450, Perplexity: 10.4337
# Epoch [1/3], Step [13100/41412], Loss: 2.8153, Perplexity: 16.6977
# Epoch [1/3], Step [13200/41412], Loss: 2.4909, Perplexity: 12.0727
# Epoch [1/3], Step [13300/41412], Loss: 3.0859, Perplexity: 21.8871
# Epoch [1/3], Step [13400/41412], Loss: 2.5206, Perplexity: 12.4362
# Epoch [1/3], Step [13500/41412], Loss: 2.8746, Perplexity: 17.7176
# Epoch [1/3], Step [13600/41412], Loss: 2.9098, Perplexity: 18.3540
# Epoch [1/3], Step [13700/41412], Loss: 2.8627, Perplexity: 17.5089
# Epoch [1/3], Step [13800/41412], Loss: 2.3786, Perplexity: 10.7902
# Epoch [1/3], Step [13900/41412], Loss: 2.1705, Perplexity: 8.76313
# Epoch [1/3], Step [14000/41412], Loss: 2.8062, Perplexity: 16.5467
# Epoch [1/3], Step [14100/41412], Loss: 2.4977, Perplexity: 12.1546
# Epoch [1/3], Step [14200/41412], Loss: 2.5980, Perplexity: 13.43701
# Epoch [1/3], Step [14300/41412], Loss: 2.6514, Perplexity: 14.1732
# Epoch [1/3], Step [14400/41412], Loss: 2.2516, Perplexity: 9.50262
# Epoch [1/3], Step [14500/41412], Loss: 2.4277, Perplexity: 11.3327
# Epoch [1/3], Step [14600/41412], Loss: 2.2615, Perplexity: 9.59779
# Epoch [1/3], Step [14700/41412], Loss: 2.2390, Perplexity: 9.38363
# Epoch [1/3], Step [14800/41412], Loss: 2.5174, Perplexity: 12.3966
# Epoch [1/3], Step [14900/41412], Loss: 2.3752, Perplexity: 10.7536
# Epoch [1/3], Step [15000/41412], Loss: 2.4187, Perplexity: 11.2317
# Epoch [1/3], Step [15100/41412], Loss: 2.4378, Perplexity: 11.4481
# Epoch [1/3], Step [15200/41412], Loss: 3.0361, Perplexity: 20.8248
# Epoch [1/3], Step [15300/41412], Loss: 2.1276, Perplexity: 8.39440
# Epoch [1/3], Step [15400/41412], Loss: 2.6214, Perplexity: 13.7548
# Epoch [1/3], Step [15500/41412], Loss: 2.2041, Perplexity: 9.06218
# Epoch [1/3], Step [15600/41412], Loss: 2.4581, Perplexity: 11.6828
# Epoch [1/3], Step [15700/41412], Loss: 2.4912, Perplexity: 12.0762
# Epoch [1/3], Step [15800/41412], Loss: 2.5596, Perplexity: 12.9305
# Epoch [1/3], Step [15900/41412], Loss: 2.3977, Perplexity: 10.9976
# Epoch [1/3], Step [16000/41412], Loss: 2.8564, Perplexity: 17.3990
# Epoch [1/3], Step [16100/41412], Loss: 2.6042, Perplexity: 13.5205
# Epoch [1/3], Step [16200/41412], Loss: 3.0256, Perplexity: 20.6064
# Epoch [1/3], Step [16300/41412], Loss: 2.0499, Perplexity: 7.76713
# Epoch [1/3], Step [16400/41412], Loss: 2.6611, Perplexity: 14.3122
# Epoch [1/3], Step [16500/41412], Loss: 2.7731, Perplexity: 16.0075
# Epoch [1/3], Step [16600/41412], Loss: 2.9030, Perplexity: 18.2283
# Epoch [1/3], Step [16700/41412], Loss: 2.4394, Perplexity: 11.4665
# Epoch [1/3], Step [16800/41412], Loss: 2.2589, Perplexity: 9.57238
# Epoch [1/3], Step [16900/41412], Loss: 2.4157, Perplexity: 11.1981
# Epoch [1/3], Step [17000/41412], Loss: 2.6754, Perplexity: 14.5181
# Epoch [1/3], Step [17100/41412], Loss: 2.2982, Perplexity: 9.95598
# Epoch [1/3], Step [17200/41412], Loss: 2.3869, Perplexity: 10.8800
# Epoch [1/3], Step [17300/41412], Loss: 2.4216, Perplexity: 11.2636
# Epoch [1/3], Step [17400/41412], Loss: 2.2457, Perplexity: 9.44744
# Epoch [1/3], Step [17500/41412], Loss: 3.1698, Perplexity: 23.8035
# Epoch [1/3], Step [17600/41412], Loss: 2.2327, Perplexity: 9.32463
# Epoch [1/3], Step [17700/41412], Loss: 2.6317, Perplexity: 13.8976
# Epoch [1/3], Step [17800/41412], Loss: 2.0947, Perplexity: 8.12269
# Epoch [1/3], Step [17900/41412], Loss: 2.7152, Perplexity: 15.1080
# Epoch [1/3], Step [18000/41412], Loss: 3.4332, Perplexity: 30.9765
# Epoch [1/3], Step [18100/41412], Loss: 2.3327, Perplexity: 10.3054
# Epoch [1/3], Step [18200/41412], Loss: 2.3752, Perplexity: 10.7535
# Epoch [1/3], Step [18300/41412], Loss: 2.1591, Perplexity: 8.66366
# Epoch [1/3], Step [18400/41412], Loss: 2.4290, Perplexity: 11.3474
# Epoch [1/3], Step [18500/41412], Loss: 2.7847, Perplexity: 16.1950
# Epoch [1/3], Step [18600/41412], Loss: 2.1203, Perplexity: 8.33361
# Epoch [1/3], Step [18700/41412], Loss: 3.1931, Perplexity: 24.3647
# Epoch [1/3], Step [18800/41412], Loss: 2.3485, Perplexity: 10.4696
# Epoch [1/3], Step [18900/41412], Loss: 2.5785, Perplexity: 13.1773
# Epoch [1/3], Step [19000/41412], Loss: 2.2276, Perplexity: 9.27797
# Epoch [1/3], Step [19100/41412], Loss: 3.2574, Perplexity: 25.9817
# Epoch [1/3], Step [19200/41412], Loss: 2.1954, Perplexity: 8.98390
# Epoch [1/3], Step [19300/41412], Loss: 2.4402, Perplexity: 11.4757
# Epoch [1/3], Step [19400/41412], Loss: 2.5999, Perplexity: 13.46214
# Epoch [1/3], Step [19500/41412], Loss: 2.3475, Perplexity: 10.4592
# Epoch [1/3], Step [19600/41412], Loss: 2.6352, Perplexity: 13.9461
# Epoch [1/3], Step [19700/41412], Loss: 2.5552, Perplexity: 12.8738
# Epoch [1/3], Step [19800/41412], Loss: 2.1614, Perplexity: 8.68308
# Epoch [1/3], Step [19900/41412], Loss: 2.7701, Perplexity: 15.9601
# Epoch [1/3], Step [20000/41412], Loss: 2.7634, Perplexity: 15.8542
# Epoch [1/3], Step [20100/41412], Loss: 1.9795, Perplexity: 7.23920
# Epoch [1/3], Step [20200/41412], Loss: 2.6704, Perplexity: 14.4452
# Epoch [1/3], Step [20300/41412], Loss: 2.0271, Perplexity: 7.59219
# Epoch [1/3], Step [20400/41412], Loss: 2.9602, Perplexity: 19.3013
# Epoch [1/3], Step [20500/41412], Loss: 2.6624, Perplexity: 14.3305
# Epoch [1/3], Step [20600/41412], Loss: 2.3691, Perplexity: 10.6874
# Epoch [1/3], Step [20700/41412], Loss: 2.5881, Perplexity: 13.3049
# Epoch [1/3], Step [20800/41412], Loss: 2.1622, Perplexity: 8.69014
# Epoch [1/3], Step [20900/41412], Loss: 2.4934, Perplexity: 12.1019
# Epoch [1/3], Step [21000/41412], Loss: 2.9581, Perplexity: 19.2614
# Epoch [1/3], Step [21100/41412], Loss: 2.0071, Perplexity: 7.44168
# Epoch [1/3], Step [21200/41412], Loss: 3.1179, Perplexity: 22.5990
# Epoch [1/3], Step [21300/41412], Loss: 2.4097, Perplexity: 11.1305
# Epoch [1/3], Step [21400/41412], Loss: 2.2920, Perplexity: 9.89446
# Epoch [1/3], Step [21500/41412], Loss: 2.0759, Perplexity: 7.97162
# Epoch [1/3], Step [21600/41412], Loss: 2.0816, Perplexity: 8.01690
# Epoch [1/3], Step [21700/41412], Loss: 2.5365, Perplexity: 12.6349
# Epoch [1/3], Step [21800/41412], Loss: 2.5401, Perplexity: 12.6804
# Epoch [1/3], Step [21900/41412], Loss: 3.3753, Perplexity: 29.2341
# Epoch [1/3], Step [22000/41412], Loss: 2.8551, Perplexity: 17.3765
# Epoch [1/3], Step [22100/41412], Loss: 1.8919, Perplexity: 6.63194
# Epoch [1/3], Step [22200/41412], Loss: 2.1912, Perplexity: 8.94567
# Epoch [1/3], Step [22300/41412], Loss: 2.3524, Perplexity: 10.5107
# Epoch [1/3], Step [22400/41412], Loss: 2.3256, Perplexity: 10.2332
# Epoch [1/3], Step [22500/41412], Loss: 2.0295, Perplexity: 7.610696
# Epoch [1/3], Step [22600/41412], Loss: 2.5283, Perplexity: 12.5319
# Epoch [1/3], Step [22700/41412], Loss: 2.0007, Perplexity: 7.39424
# Epoch [1/3], Step [22800/41412], Loss: 2.6424, Perplexity: 14.0463
# Epoch [1/3], Step [22900/41412], Loss: 2.3710, Perplexity: 10.7085
# Epoch [1/3], Step [23000/41412], Loss: 2.3914, Perplexity: 10.92914
# Epoch [1/3], Step [23100/41412], Loss: 2.6497, Perplexity: 14.1502
# Epoch [1/3], Step [23200/41412], Loss: 2.1898, Perplexity: 8.93310
# Epoch [1/3], Step [23300/41412], Loss: 2.6339, Perplexity: 13.9277
# Epoch [1/3], Step [23400/41412], Loss: 2.4694, Perplexity: 11.8155
# Epoch [1/3], Step [23500/41412], Loss: 2.7782, Perplexity: 16.0895
# Epoch [1/3], Step [23600/41412], Loss: 2.7000, Perplexity: 14.8799
# Epoch [1/3], Step [23700/41412], Loss: 2.8710, Perplexity: 17.6539
# Epoch [1/3], Step [23800/41412], Loss: 2.3404, Perplexity: 10.3855
# Epoch [1/3], Step [23900/41412], Loss: 2.2118, Perplexity: 9.13178
# Epoch [1/3], Step [24000/41412], Loss: 2.0343, Perplexity: 7.64713
# Epoch [1/3], Step [24100/41412], Loss: 2.1659, Perplexity: 8.72263
# Epoch [1/3], Step [24200/41412], Loss: 2.1342, Perplexity: 8.45056
# Epoch [1/3], Step [24300/41412], Loss: 2.0947, Perplexity: 8.12297
# Epoch [1/3], Step [24400/41412], Loss: 2.3022, Perplexity: 9.99590
# Epoch [1/3], Step [24500/41412], Loss: 1.9431, Perplexity: 6.98025
# Epoch [1/3], Step [24600/41412], Loss: 2.9218, Perplexity: 18.5746
# Epoch [1/3], Step [24700/41412], Loss: 1.8498, Perplexity: 6.35884
# Epoch [1/3], Step [24800/41412], Loss: 2.9364, Perplexity: 18.8472
# Epoch [1/3], Step [24900/41412], Loss: 2.3927, Perplexity: 10.9428
# Epoch [1/3], Step [25000/41412], Loss: 2.0212, Perplexity: 7.54762
# Epoch [1/3], Step [25100/41412], Loss: 2.0413, Perplexity: 7.70030
# Epoch [1/3], Step [25200/41412], Loss: 2.0038, Perplexity: 7.41706
# Epoch [1/3], Step [25300/41412], Loss: 2.4163, Perplexity: 11.2041
# Epoch [1/3], Step [25400/41412], Loss: 2.1117, Perplexity: 8.26237
# Epoch [1/3], Step [25500/41412], Loss: 2.3636, Perplexity: 10.6294
# Epoch [1/3], Step [25600/41412], Loss: 2.5037, Perplexity: 12.2278
# Epoch [1/3], Step [25700/41412], Loss: 2.7410, Perplexity: 15.5029
# Epoch [1/3], Step [25800/41412], Loss: 2.5260, Perplexity: 12.5034
# Epoch [1/3], Step [25900/41412], Loss: 2.1156, Perplexity: 8.29463
# Epoch [1/3], Step [26000/41412], Loss: 2.8922, Perplexity: 18.0333
# Epoch [1/3], Step [26100/41412], Loss: 2.0681, Perplexity: 7.91009
# Epoch [1/3], Step [26200/41412], Loss: 1.8563, Perplexity: 6.39988
# Epoch [1/3], Step [26300/41412], Loss: 1.9534, Perplexity: 7.05235
# Epoch [1/3], Step [26400/41412], Loss: 2.0904, Perplexity: 8.08850
# Epoch [1/3], Step [26500/41412], Loss: 2.2234, Perplexity: 9.23873
# Epoch [1/3], Step [26600/41412], Loss: 2.2998, Perplexity: 9.97229
# Epoch [1/3], Step [26700/41412], Loss: 1.9430, Perplexity: 6.98008
# Epoch [1/3], Step [26800/41412], Loss: 2.3070, Perplexity: 10.0445
# Epoch [1/3], Step [26900/41412], Loss: 2.3229, Perplexity: 10.2050
# Epoch [1/3], Step [27000/41412], Loss: 2.1183, Perplexity: 8.31715
# Epoch [1/3], Step [27100/41412], Loss: 1.8036, Perplexity: 6.07124
# Epoch [1/3], Step [27200/41412], Loss: 2.4609, Perplexity: 11.7148
# Epoch [1/3], Step [27300/41412], Loss: 2.3052, Perplexity: 10.0266
# Epoch [1/3], Step [27400/41412], Loss: 1.9952, Perplexity: 7.35387
# Epoch [1/3], Step [27500/41412], Loss: 2.3484, Perplexity: 10.4687
# Epoch [1/3], Step [27600/41412], Loss: 2.3244, Perplexity: 10.2207
# Epoch [1/3], Step [27700/41412], Loss: 2.2322, Perplexity: 9.32039
# Epoch [1/3], Step [27800/41412], Loss: 2.4709, Perplexity: 11.8333
# Epoch [1/3], Step [27900/41412], Loss: 2.3936, Perplexity: 10.9528
# Epoch [1/3], Step [28000/41412], Loss: 2.2357, Perplexity: 9.35353
# Epoch [1/3], Step [28100/41412], Loss: 2.3106, Perplexity: 10.0805
# Epoch [1/3], Step [28200/41412], Loss: 1.8907, Perplexity: 6.62384
# Epoch [1/3], Step [28300/41412], Loss: 2.1677, Perplexity: 8.73846
# Epoch [1/3], Step [28400/41412], Loss: 1.9812, Perplexity: 7.25122
# Epoch [1/3], Step [28500/41412], Loss: 2.4039, Perplexity: 11.0657
# Epoch [1/3], Step [28600/41412], Loss: 2.1503, Perplexity: 8.58704
# Epoch [1/3], Step [28700/41412], Loss: 2.4883, Perplexity: 12.0405
# Epoch [1/3], Step [28800/41412], Loss: 3.0321, Perplexity: 20.7407
# Epoch [1/3], Step [28900/41412], Loss: 2.4831, Perplexity: 11.9787
# Epoch [1/3], Step [29000/41412], Loss: 2.3486, Perplexity: 10.4706
# Epoch [1/3], Step [29100/41412], Loss: 2.7058, Perplexity: 14.9669
# Epoch [1/3], Step [29200/41412], Loss: 2.1614, Perplexity: 8.68343
# Epoch [1/3], Step [29300/41412], Loss: 2.0126, Perplexity: 7.48314
# Epoch [1/3], Step [29400/41412], Loss: 2.6905, Perplexity: 14.7397
# Epoch [1/3], Step [29500/41412], Loss: 2.3738, Perplexity: 10.7384
# Epoch [1/3], Step [29600/41412], Loss: 2.7368, Perplexity: 15.4377
# Epoch [1/3], Step [29700/41412], Loss: 2.3272, Perplexity: 10.2496
# Epoch [1/3], Step [29800/41412], Loss: 2.0590, Perplexity: 7.83827
# Epoch [1/3], Step [29900/41412], Loss: 2.6980, Perplexity: 14.8506
# Epoch [1/3], Step [30000/41412], Loss: 2.2956, Perplexity: 9.93014
# Epoch [1/3], Step [30100/41412], Loss: 2.4291, Perplexity: 11.3488
# Epoch [1/3], Step [30200/41412], Loss: 2.7359, Perplexity: 15.4242
# Epoch [1/3], Step [30300/41412], Loss: 2.0177, Perplexity: 7.52124
# Epoch [1/3], Step [30400/41412], Loss: 2.4575, Perplexity: 11.6750
# Epoch [1/3], Step [30500/41412], Loss: 2.6589, Perplexity: 14.2811
# Epoch [1/3], Step [30600/41412], Loss: 2.6458, Perplexity: 14.0941
# Epoch [1/3], Step [30700/41412], Loss: 2.4099, Perplexity: 11.1326
# Epoch [1/3], Step [30800/41412], Loss: 2.9824, Perplexity: 19.7351
# Epoch [1/3], Step [30900/41412], Loss: 2.6851, Perplexity: 14.6600
# Epoch [1/3], Step [31000/41412], Loss: 2.4947, Perplexity: 12.1183
# Epoch [1/3], Step [31100/41412], Loss: 2.6116, Perplexity: 13.6202
# Epoch [1/3], Step [31200/41412], Loss: 2.3227, Perplexity: 10.2027
# Epoch [1/3], Step [31300/41412], Loss: 2.9093, Perplexity: 18.3441
# Epoch [1/3], Step [31400/41412], Loss: 1.8702, Perplexity: 6.48976
# Epoch [1/3], Step [31500/41412], Loss: 2.7036, Perplexity: 14.9327
# Epoch [1/3], Step [31600/41412], Loss: 2.5000, Perplexity: 12.1825
# Epoch [1/3], Step [31700/41412], Loss: 2.6375, Perplexity: 13.9788
# Epoch [1/3], Step [31800/41412], Loss: 2.3965, Perplexity: 10.9848
# Epoch [1/3], Step [31900/41412], Loss: 2.6510, Perplexity: 14.1679
# Epoch [1/3], Step [32000/41412], Loss: 2.1874, Perplexity: 8.91163
# Epoch [1/3], Step [32100/41412], Loss: 2.5662, Perplexity: 13.0166
# Epoch [1/3], Step [32200/41412], Loss: 2.9081, Perplexity: 18.3226
# Epoch [1/3], Step [32300/41412], Loss: 2.4547, Perplexity: 11.6430
# Epoch [1/3], Step [32400/41412], Loss: 2.2817, Perplexity: 9.79296
# Epoch [1/3], Step [32500/41412], Loss: 2.0365, Perplexity: 7.66389
# Epoch [1/3], Step [32600/41412], Loss: 2.4984, Perplexity: 12.1631
# Epoch [1/3], Step [32700/41412], Loss: 2.1535, Perplexity: 8.61485
# Epoch [1/3], Step [32800/41412], Loss: 2.6518, Perplexity: 14.1792
# Epoch [1/3], Step [32900/41412], Loss: 2.9128, Perplexity: 18.4085
# Epoch [1/3], Step [33000/41412], Loss: 2.6485, Perplexity: 14.1326
# Epoch [1/3], Step [33100/41412], Loss: 1.9428, Perplexity: 6.97835
# Epoch [1/3], Step [33200/41412], Loss: 2.0240, Perplexity: 7.56841
# Epoch [1/3], Step [33300/41412], Loss: 2.0831, Perplexity: 8.02934
# Epoch [1/3], Step [33400/41412], Loss: 1.9523, Perplexity: 7.04514
# Epoch [1/3], Step [33500/41412], Loss: 2.2836, Perplexity: 9.81154
# Epoch [1/3], Step [33600/41412], Loss: 5.3652, Perplexity: 213.8268
# Epoch [1/3], Step [33700/41412], Loss: 2.3670, Perplexity: 10.6649
# Epoch [1/3], Step [33800/41412], Loss: 2.0744, Perplexity: 7.96008
# Epoch [1/3], Step [33900/41412], Loss: 2.5239, Perplexity: 12.4766
# Epoch [1/3], Step [34000/41412], Loss: 2.1964, Perplexity: 8.99256
# Epoch [1/3], Step [34100/41412], Loss: 2.2280, Perplexity: 9.28141
# Epoch [1/3], Step [34200/41412], Loss: 2.4052, Perplexity: 11.0809
# Epoch [1/3], Step [34300/41412], Loss: 2.1888, Perplexity: 8.92493
# Epoch [1/3], Step [34400/41412], Loss: 2.3202, Perplexity: 10.1778
# Epoch [1/3], Step [34500/41412], Loss: 2.4745, Perplexity: 11.8755
# Epoch [1/3], Step [34600/41412], Loss: 2.3871, Perplexity: 10.8824
# Epoch [1/3], Step [34700/41412], Loss: 2.4765, Perplexity: 11.8991
# Epoch [1/3], Step [34800/41412], Loss: 2.2482, Perplexity: 9.47060
# Epoch [1/3], Step [34900/41412], Loss: 2.5608, Perplexity: 12.9457
# Epoch [1/3], Step [35000/41412], Loss: 2.5304, Perplexity: 12.5583
# Epoch [1/3], Step [35100/41412], Loss: 2.6510, Perplexity: 14.1679
# Epoch [1/3], Step [35200/41412], Loss: 2.4816, Perplexity: 11.9608
# Epoch [1/3], Step [35300/41412], Loss: 2.4441, Perplexity: 11.5204
# Epoch [1/3], Step [35400/41412], Loss: 1.8737, Perplexity: 6.51233
# Epoch [1/3], Step [35500/41412], Loss: 2.0699, Perplexity: 7.92408
# Epoch [1/3], Step [35600/41412], Loss: 2.2366, Perplexity: 9.36197
# Epoch [1/3], Step [35700/41412], Loss: 2.0891, Perplexity: 8.07779
# Epoch [1/3], Step [35800/41412], Loss: 2.4876, Perplexity: 12.0325
# Epoch [1/3], Step [35900/41412], Loss: 2.1356, Perplexity: 8.46196
# Epoch [1/3], Step [36000/41412], Loss: 2.4313, Perplexity: 11.3737
# Epoch [1/3], Step [36100/41412], Loss: 2.4683, Perplexity: 11.8019
# Epoch [1/3], Step [36200/41412], Loss: 2.6869, Perplexity: 14.6862
# Epoch [1/3], Step [36300/41412], Loss: 2.2756, Perplexity: 9.73361
# Epoch [1/3], Step [36400/41412], Loss: 2.4664, Perplexity: 11.7800
# Epoch [1/3], Step [36500/41412], Loss: 2.4598, Perplexity: 11.7027
# Epoch [1/3], Step [36600/41412], Loss: 2.4459, Perplexity: 11.5409
# Epoch [1/3], Step [36700/41412], Loss: 2.7421, Perplexity: 15.5196
# Epoch [1/3], Step [36800/41412], Loss: 2.2253, Perplexity: 9.25622
# Epoch [1/3], Step [36900/41412], Loss: 2.4472, Perplexity: 11.55583
# Epoch [1/3], Step [37000/41412], Loss: 2.1174, Perplexity: 8.30988
# Epoch [1/3], Step [37100/41412], Loss: 2.1086, Perplexity: 8.23675
# Epoch [1/3], Step [37200/41412], Loss: 2.5663, Perplexity: 13.0175
# Epoch [1/3], Step [37300/41412], Loss: 2.1821, Perplexity: 8.86528
# Epoch [1/3], Step [37400/41412], Loss: 1.8799, Perplexity: 6.55295
# Epoch [1/3], Step [37500/41412], Loss: 2.5543, Perplexity: 12.8619
# Epoch [1/3], Step [37600/41412], Loss: 2.6326, Perplexity: 13.9098
# Epoch [1/3], Step [37700/41412], Loss: 2.1445, Perplexity: 8.53797
# Epoch [1/3], Step [37800/41412], Loss: 2.2172, Perplexity: 9.18124
# Epoch [1/3], Step [37900/41412], Loss: 2.4597, Perplexity: 11.7013
# Epoch [1/3], Step [38000/41412], Loss: 2.2672, Perplexity: 9.65230
# Epoch [1/3], Step [38100/41412], Loss: 2.4159, Perplexity: 11.1999
# Epoch [1/3], Step [38200/41412], Loss: 1.8248, Perplexity: 6.20171
# Epoch [1/3], Step [38300/41412], Loss: 2.4425, Perplexity: 11.5014
# Epoch [1/3], Step [38400/41412], Loss: 2.3977, Perplexity: 10.9980
# Epoch [1/3], Step [38500/41412], Loss: 1.9414, Perplexity: 6.96836
# Epoch [1/3], Step [38600/41412], Loss: 2.4431, Perplexity: 11.5087
# Epoch [1/3], Step [38700/41412], Loss: 2.6443, Perplexity: 14.0736
# Epoch [1/3], Step [38800/41412], Loss: 2.2300, Perplexity: 9.30009
# Epoch [1/3], Step [38900/41412], Loss: 2.7145, Perplexity: 15.0971
# Epoch [1/3], Step [39000/41412], Loss: 2.8394, Perplexity: 17.1059
# Epoch [1/3], Step [39100/41412], Loss: 2.7360, Perplexity: 15.4245
# Epoch [1/3], Step [39200/41412], Loss: 2.3251, Perplexity: 10.2276
# Epoch [1/3], Step [39300/41412], Loss: 2.8009, Perplexity: 16.4588
# Epoch [1/3], Step [39400/41412], Loss: 2.4923, Perplexity: 12.0888
# Epoch [1/3], Step [39500/41412], Loss: 2.6750, Perplexity: 14.5123
# Epoch [1/3], Step [39600/41412], Loss: 2.5103, Perplexity: 12.3083
# Epoch [1/3], Step [39700/41412], Loss: 2.7286, Perplexity: 15.3109
# Epoch [1/3], Step [39800/41412], Loss: 2.3585, Perplexity: 10.5754
# Epoch [1/3], Step [39900/41412], Loss: 2.7304, Perplexity: 15.3384
# Epoch [1/3], Step [40000/41412], Loss: 2.1770, Perplexity: 8.81978
# Epoch [1/3], Step [40100/41412], Loss: 2.5925, Perplexity: 13.3636
# Epoch [1/3], Step [40200/41412], Loss: 2.3489, Perplexity: 10.4738
# Epoch [1/3], Step [40300/41412], Loss: 2.9163, Perplexity: 18.4732
# Epoch [1/3], Step [40400/41412], Loss: 1.9585, Perplexity: 7.08890
# Epoch [1/3], Step [40500/41412], Loss: 2.0696, Perplexity: 7.92180
# Epoch [1/3], Step [40600/41412], Loss: 2.3241, Perplexity: 10.2177
# Epoch [1/3], Step [40700/41412], Loss: 2.2991, Perplexity: 9.96567
# Epoch [1/3], Step [40800/41412], Loss: 2.1801, Perplexity: 8.84705
# Epoch [1/3], Step [40900/41412], Loss: 2.2220, Perplexity: 9.22595
# Epoch [1/3], Step [41000/41412], Loss: 2.1987, Perplexity: 9.01314
# Epoch [1/3], Step [41100/41412], Loss: 2.8138, Perplexity: 16.6727
# Epoch [1/3], Step [41200/41412], Loss: 2.4469, Perplexity: 11.5526
# Epoch [1/3], Step [41300/41412], Loss: 2.5561, Perplexity: 12.8859
# Epoch [1/3], Step [41400/41412], Loss: 2.3698, Perplexity: 10.6950
# Epoch [2/3], Step [100/41412], Loss: 2.3445, Perplexity: 10.428331
# Epoch [2/3], Step [200/41412], Loss: 2.6591, Perplexity: 14.2839
# Epoch [2/3], Step [300/41412], Loss: 2.7195, Perplexity: 15.1725
# Epoch [2/3], Step [400/41412], Loss: 2.8846, Perplexity: 17.8957
# Epoch [2/3], Step [500/41412], Loss: 1.8473, Perplexity: 6.34268
# Epoch [2/3], Step [600/41412], Loss: 1.9465, Perplexity: 7.00394
# Epoch [2/3], Step [700/41412], Loss: 2.5146, Perplexity: 12.3614
# Epoch [2/3], Step [800/41412], Loss: 2.6547, Perplexity: 14.2207
# Epoch [2/3], Step [900/41412], Loss: 2.9229, Perplexity: 18.5953
# Epoch [2/3], Step [1000/41412], Loss: 2.5420, Perplexity: 12.7054
# Epoch [2/3], Step [1100/41412], Loss: 2.6030, Perplexity: 13.5037
# Epoch [2/3], Step [1200/41412], Loss: 2.0599, Perplexity: 7.84521
# Epoch [2/3], Step [1300/41412], Loss: 2.0595, Perplexity: 7.84212
# Epoch [2/3], Step [1400/41412], Loss: 2.2838, Perplexity: 9.81394
# Epoch [2/3], Step [1500/41412], Loss: 1.7687, Perplexity: 5.86335
# Epoch [2/3], Step [1600/41412], Loss: 2.4512, Perplexity: 11.6024
# Epoch [2/3], Step [1700/41412], Loss: 2.0986, Perplexity: 8.15470
# Epoch [2/3], Step [1800/41412], Loss: 2.0859, Perplexity: 8.05209
# Epoch [2/3], Step [1900/41412], Loss: 2.0580, Perplexity: 7.83035
# Epoch [2/3], Step [2000/41412], Loss: 2.8017, Perplexity: 16.4734
# Epoch [2/3], Step [2100/41412], Loss: 2.2629, Perplexity: 9.61128
# Epoch [2/3], Step [2200/41412], Loss: 2.6348, Perplexity: 13.9401
# Epoch [2/3], Step [2300/41412], Loss: 2.3830, Perplexity: 10.8371
# Epoch [2/3], Step [2400/41412], Loss: 2.4655, Perplexity: 11.7698
# Epoch [2/3], Step [2500/41412], Loss: 2.6300, Perplexity: 13.8737
# Epoch [2/3], Step [2600/41412], Loss: 2.2693, Perplexity: 9.67290
# Epoch [2/3], Step [2700/41412], Loss: 2.3593, Perplexity: 10.5838
# Epoch [2/3], Step [2800/41412], Loss: 2.6159, Perplexity: 13.6798
# Epoch [2/3], Step [2900/41412], Loss: 2.6910, Perplexity: 14.7462
# Epoch [2/3], Step [3000/41412], Loss: 2.5172, Perplexity: 12.3942
# Epoch [2/3], Step [3100/41412], Loss: 2.4141, Perplexity: 11.1795
# Epoch [2/3], Step [3200/41412], Loss: 1.8197, Perplexity: 6.17017
# Epoch [2/3], Step [3300/41412], Loss: 2.7339, Perplexity: 15.3922
# Epoch [2/3], Step [3400/41412], Loss: 2.2044, Perplexity: 9.06529
# Epoch [2/3], Step [3500/41412], Loss: 2.4973, Perplexity: 12.1496
# Epoch [2/3], Step [3600/41412], Loss: 2.8315, Perplexity: 16.9716
# Epoch [2/3], Step [3700/41412], Loss: 2.2331, Perplexity: 9.32872
# Epoch [2/3], Step [3800/41412], Loss: 2.7432, Perplexity: 15.5360
# Epoch [2/3], Step [3900/41412], Loss: 2.3521, Perplexity: 10.5081
# Epoch [2/3], Step [4000/41412], Loss: 1.9234, Perplexity: 6.84450
# Epoch [2/3], Step [4100/41412], Loss: 1.8928, Perplexity: 6.63782
# Epoch [2/3], Step [4200/41412], Loss: 3.2109, Perplexity: 24.8010
# Epoch [2/3], Step [4300/41412], Loss: 2.8202, Perplexity: 16.7800
# Epoch [2/3], Step [4400/41412], Loss: 1.8960, Perplexity: 6.65943
# Epoch [2/3], Step [4500/41412], Loss: 2.0060, Perplexity: 7.433406
# Epoch [2/3], Step [4600/41412], Loss: 2.1261, Perplexity: 8.38227
# Epoch [2/3], Step [4700/41412], Loss: 2.1336, Perplexity: 8.44508
# Epoch [2/3], Step [4800/41412], Loss: 2.1716, Perplexity: 8.77276
# Epoch [2/3], Step [4900/41412], Loss: 2.2217, Perplexity: 9.22263
# Epoch [2/3], Step [5000/41412], Loss: 2.5115, Perplexity: 12.3236
# Epoch [2/3], Step [5100/41412], Loss: 2.3156, Perplexity: 10.1307
# Epoch [2/3], Step [5200/41412], Loss: 2.1088, Perplexity: 8.23825
# Epoch [2/3], Step [5300/41412], Loss: 2.4216, Perplexity: 11.2638
# Epoch [2/3], Step [5400/41412], Loss: 1.8403, Perplexity: 6.29854
# Epoch [2/3], Step [5500/41412], Loss: 2.2564, Perplexity: 9.54900
# Epoch [2/3], Step [5600/41412], Loss: 1.7706, Perplexity: 5.87416
# Epoch [2/3], Step [5700/41412], Loss: 2.8826, Perplexity: 17.8610
# Epoch [2/3], Step [5800/41412], Loss: 2.1533, Perplexity: 8.61344
# Epoch [2/3], Step [5900/41412], Loss: 2.0358, Perplexity: 7.65835
# Epoch [2/3], Step [6000/41412], Loss: 2.1357, Perplexity: 8.46339
# Epoch [2/3], Step [6100/41412], Loss: 1.9220, Perplexity: 6.83472
# Epoch [2/3], Step [6200/41412], Loss: 2.4595, Perplexity: 11.6984
# Epoch [2/3], Step [6300/41412], Loss: 1.9729, Perplexity: 7.19149
# Epoch [2/3], Step [6400/41412], Loss: 2.0831, Perplexity: 8.02928
# Epoch [2/3], Step [6500/41412], Loss: 2.4884, Perplexity: 12.0415
# Epoch [2/3], Step [6600/41412], Loss: 2.6712, Perplexity: 14.4566
# Epoch [2/3], Step [6700/41412], Loss: 2.1085, Perplexity: 8.23616
# Epoch [2/3], Step [6800/41412], Loss: 2.6231, Perplexity: 13.7781
# Epoch [2/3], Step [6900/41412], Loss: 1.9604, Perplexity: 7.10240
# Epoch [2/3], Step [7000/41412], Loss: 2.2363, Perplexity: 9.35844
# Epoch [2/3], Step [7100/41412], Loss: 2.4144, Perplexity: 11.1829
# Epoch [2/3], Step [7200/41412], Loss: 2.4771, Perplexity: 11.9071
# Epoch [2/3], Step [7300/41412], Loss: 2.4128, Perplexity: 11.1652
# Epoch [2/3], Step [7400/41412], Loss: 2.1150, Perplexity: 8.28977
# Epoch [2/3], Step [7500/41412], Loss: 2.5348, Perplexity: 12.6133
# Epoch [2/3], Step [7600/41412], Loss: 2.3443, Perplexity: 10.4264
# Epoch [2/3], Step [7700/41412], Loss: 2.6011, Perplexity: 13.4785
# Epoch [2/3], Step [7800/41412], Loss: 2.1455, Perplexity: 8.54601
# Epoch [2/3], Step [7900/41412], Loss: 3.2638, Perplexity: 26.1483
# Epoch [2/3], Step [8000/41412], Loss: 2.0041, Perplexity: 7.41948
# Epoch [2/3], Step [8100/41412], Loss: 2.8654, Perplexity: 17.5568
# Epoch [2/3], Step [8200/41412], Loss: 2.3508, Perplexity: 10.4938
# Epoch [2/3], Step [8300/41412], Loss: 3.0408, Perplexity: 20.9230
# Epoch [2/3], Step [8400/41412], Loss: 2.2012, Perplexity: 9.03567
# Epoch [2/3], Step [8500/41412], Loss: 2.3133, Perplexity: 10.1080
# Epoch [2/3], Step [8600/41412], Loss: 2.7635, Perplexity: 15.8551
# Epoch [2/3], Step [8700/41412], Loss: 2.3890, Perplexity: 10.9027
# Epoch [2/3], Step [8800/41412], Loss: 2.2149, Perplexity: 9.16097
# Epoch [2/3], Step [8900/41412], Loss: 2.1156, Perplexity: 8.29495
# Epoch [2/3], Step [9000/41412], Loss: 2.2879, Perplexity: 9.85429
# Epoch [2/3], Step [9100/41412], Loss: 2.0630, Perplexity: 7.86938
# Epoch [2/3], Step [9200/41412], Loss: 1.8935, Perplexity: 6.64233
# Epoch [2/3], Step [9300/41412], Loss: 2.7596, Perplexity: 15.7941
# Epoch [2/3], Step [9400/41412], Loss: 2.4217, Perplexity: 11.2645
# Epoch [2/3], Step [9500/41412], Loss: 2.2092, Perplexity: 9.10811
# Epoch [2/3], Step [9600/41412], Loss: 2.8109, Perplexity: 16.6253
# Epoch [2/3], Step [9700/41412], Loss: 2.3212, Perplexity: 10.1879
# Epoch [2/3], Step [9800/41412], Loss: 1.9233, Perplexity: 6.84356
# Epoch [2/3], Step [9900/41412], Loss: 2.1439, Perplexity: 8.53236
# Epoch [2/3], Step [10000/41412], Loss: 2.1496, Perplexity: 8.5813
# Epoch [2/3], Step [10100/41412], Loss: 2.2427, Perplexity: 9.41896
# Epoch [2/3], Step [10200/41412], Loss: 2.0825, Perplexity: 8.02440
# Epoch [2/3], Step [10300/41412], Loss: 2.1650, Perplexity: 8.71492
# Epoch [2/3], Step [10400/41412], Loss: 2.4243, Perplexity: 11.2947
# Epoch [2/3], Step [10500/41412], Loss: 2.8283, Perplexity: 16.9163
# Epoch [2/3], Step [10600/41412], Loss: 1.9870, Perplexity: 7.29391
# Epoch [2/3], Step [10700/41412], Loss: 2.6665, Perplexity: 14.3892
# Epoch [2/3], Step [10800/41412], Loss: 2.2225, Perplexity: 9.23038
# Epoch [2/3], Step [10900/41412], Loss: 2.2391, Perplexity: 9.38514
# Epoch [2/3], Step [11000/41412], Loss: 2.4092, Perplexity: 11.1254
# Epoch [2/3], Step [11100/41412], Loss: 2.1262, Perplexity: 8.38314
# Epoch [2/3], Step [11200/41412], Loss: 2.3412, Perplexity: 10.3939
# Epoch [2/3], Step [11300/41412], Loss: 1.8234, Perplexity: 6.19307
# Epoch [2/3], Step [11400/41412], Loss: 2.2898, Perplexity: 9.87316
# Epoch [2/3], Step [11500/41412], Loss: 2.3084, Perplexity: 10.0584
# Epoch [2/3], Step [11600/41412], Loss: 2.4120, Perplexity: 11.1562
# Epoch [2/3], Step [11700/41412], Loss: 2.6609, Perplexity: 14.3091
# Epoch [2/3], Step [11800/41412], Loss: 2.0472, Perplexity: 7.74601
# Epoch [2/3], Step [11900/41412], Loss: 2.0656, Perplexity: 7.88982
# Epoch [2/3], Step [12000/41412], Loss: 2.0716, Perplexity: 7.93730
# Epoch [2/3], Step [12100/41412], Loss: 2.5304, Perplexity: 12.5582
# Epoch [2/3], Step [12200/41412], Loss: 2.4322, Perplexity: 11.38340
# Epoch [2/3], Step [12300/41412], Loss: 2.4077, Perplexity: 11.1086
# Epoch [2/3], Step [12400/41412], Loss: 2.4539, Perplexity: 11.63373
# Epoch [2/3], Step [12500/41412], Loss: 2.6176, Perplexity: 13.7023
# Epoch [2/3], Step [12600/41412], Loss: 2.1720, Perplexity: 8.77580
# Epoch [2/3], Step [12700/41412], Loss: 1.8939, Perplexity: 6.64524
# Epoch [2/3], Step [12800/41412], Loss: 2.1712, Perplexity: 8.76929
# Epoch [2/3], Step [12900/41412], Loss: 3.5556, Perplexity: 35.0075
# Epoch [2/3], Step [13000/41412], Loss: 2.4207, Perplexity: 11.2536
# Epoch [2/3], Step [13100/41412], Loss: 2.1592, Perplexity: 8.66384
# Epoch [2/3], Step [13200/41412], Loss: 2.4525, Perplexity: 11.6168
# Epoch [2/3], Step [13300/41412], Loss: 2.5651, Perplexity: 13.0019
# Epoch [2/3], Step [13400/41412], Loss: 2.2610, Perplexity: 9.59230
# Epoch [2/3], Step [13500/41412], Loss: 2.2910, Perplexity: 9.88511
# Epoch [2/3], Step [13600/41412], Loss: 1.5572, Perplexity: 4.74549
# Epoch [2/3], Step [13700/41412], Loss: 2.1827, Perplexity: 8.87063
# Epoch [2/3], Step [13800/41412], Loss: 1.7652, Perplexity: 5.84268
# Epoch [2/3], Step [13900/41412], Loss: 2.6770, Perplexity: 14.5421
# Epoch [2/3], Step [14000/41412], Loss: 2.2664, Perplexity: 9.64478
# Epoch [2/3], Step [14100/41412], Loss: 2.4186, Perplexity: 11.2304
# Epoch [2/3], Step [14200/41412], Loss: 2.1064, Perplexity: 8.21856
# Epoch [2/3], Step [14300/41412], Loss: 2.1154, Perplexity: 8.29329
# Epoch [2/3], Step [14400/41412], Loss: 2.3821, Perplexity: 10.8281
# Epoch [2/3], Step [14500/41412], Loss: 2.5110, Perplexity: 12.3168
# Epoch [2/3], Step [14600/41412], Loss: 2.4105, Perplexity: 11.1391
# Epoch [2/3], Step [14700/41412], Loss: 2.0958, Perplexity: 8.13184
# Epoch [2/3], Step [14800/41412], Loss: 1.9778, Perplexity: 7.22653
# Epoch [2/3], Step [14900/41412], Loss: 2.5995, Perplexity: 13.4573
# Epoch [2/3], Step [15000/41412], Loss: 1.6597, Perplexity: 5.25776
# Epoch [2/3], Step [15100/41412], Loss: 2.0172, Perplexity: 7.51750
# Epoch [2/3], Step [15200/41412], Loss: 2.6989, Perplexity: 14.8636
# Epoch [2/3], Step [15300/41412], Loss: 2.2356, Perplexity: 9.35240
# Epoch [2/3], Step [15400/41412], Loss: 2.2508, Perplexity: 9.49520
# Epoch [2/3], Step [15500/41412], Loss: 2.1355, Perplexity: 8.46110
# Epoch [2/3], Step [15600/41412], Loss: 2.5955, Perplexity: 13.4031
# Epoch [2/3], Step [15700/41412], Loss: 2.1315, Perplexity: 8.42740
# Epoch [2/3], Step [15800/41412], Loss: 2.7838, Perplexity: 16.1810
# Epoch [2/3], Step [15900/41412], Loss: 2.1344, Perplexity: 8.45206
# Epoch [2/3], Step [16000/41412], Loss: 2.5665, Perplexity: 13.0206
# Epoch [2/3], Step [16100/41412], Loss: 1.7766, Perplexity: 5.90965
# Epoch [2/3], Step [16200/41412], Loss: 1.8255, Perplexity: 6.20622
# Epoch [2/3], Step [16300/41412], Loss: 2.1094, Perplexity: 8.24350
# Epoch [2/3], Step [16400/41412], Loss: 2.3792, Perplexity: 10.7967
# Epoch [2/3], Step [16500/41412], Loss: 2.0694, Perplexity: 7.92040
# Epoch [2/3], Step [16600/41412], Loss: 1.6733, Perplexity: 5.32983
# Epoch [2/3], Step [16700/41412], Loss: 2.6418, Perplexity: 14.0390
# Epoch [2/3], Step [16800/41412], Loss: 2.4771, Perplexity: 11.9062
# Epoch [2/3], Step [16900/41412], Loss: 1.9972, Perplexity: 7.36872
# Epoch [2/3], Step [17000/41412], Loss: 2.4345, Perplexity: 11.41079
# Epoch [2/3], Step [17100/41412], Loss: 2.3088, Perplexity: 10.0627
# Epoch [2/3], Step [17200/41412], Loss: 2.4971, Perplexity: 12.1475
# Epoch [2/3], Step [17300/41412], Loss: 1.6997, Perplexity: 5.47255
# Epoch [2/3], Step [17400/41412], Loss: 1.9497, Perplexity: 7.02678
# Epoch [2/3], Step [17500/41412], Loss: 1.7326, Perplexity: 5.65528
# Epoch [2/3], Step [17600/41412], Loss: 2.2273, Perplexity: 9.27462
# Epoch [2/3], Step [17700/41412], Loss: 2.1141, Perplexity: 8.28182
# Epoch [2/3], Step [17800/41412], Loss: 2.6756, Perplexity: 14.5204
# Epoch [2/3], Step [17900/41412], Loss: 1.9319, Perplexity: 6.90247
# Epoch [2/3], Step [18000/41412], Loss: 1.9565, Perplexity: 7.07453
# Epoch [2/3], Step [18100/41412], Loss: 2.8376, Perplexity: 17.0756
# Epoch [2/3], Step [18200/41412], Loss: 1.7577, Perplexity: 5.79896
# Epoch [2/3], Step [18300/41412], Loss: 2.0413, Perplexity: 7.70022
# Epoch [2/3], Step [18400/41412], Loss: 2.1144, Perplexity: 8.28450
# Epoch [2/3], Step [18500/41412], Loss: 2.3884, Perplexity: 10.8962
# Epoch [2/3], Step [18600/41412], Loss: 2.0293, Perplexity: 7.60863
# Epoch [2/3], Step [18700/41412], Loss: 2.5665, Perplexity: 13.0195
# Epoch [2/3], Step [18800/41412], Loss: 1.9743, Perplexity: 7.20137
# Epoch [2/3], Step [18900/41412], Loss: 2.5720, Perplexity: 13.0926
# Epoch [2/3], Step [19000/41412], Loss: 2.3729, Perplexity: 10.7287
# Epoch [2/3], Step [19100/41412], Loss: 2.4143, Perplexity: 11.1824
# Epoch [2/3], Step [19200/41412], Loss: 2.1823, Perplexity: 8.86706
# Epoch [2/3], Step [19300/41412], Loss: 2.0861, Perplexity: 8.05371
# Epoch [2/3], Step [19400/41412], Loss: 2.3660, Perplexity: 10.6550
# Epoch [2/3], Step [19500/41412], Loss: 2.7200, Perplexity: 15.1809
# Epoch [2/3], Step [19600/41412], Loss: 2.9534, Perplexity: 19.1710
# Epoch [2/3], Step [19700/41412], Loss: 2.2791, Perplexity: 9.76817
# Epoch [2/3], Step [19800/41412], Loss: 2.0933, Perplexity: 8.11145
# Epoch [2/3], Step [19900/41412], Loss: 2.0777, Perplexity: 7.98646
# Epoch [2/3], Step [20000/41412], Loss: 2.4108, Perplexity: 11.1430
# Epoch [2/3], Step [20100/41412], Loss: 2.0993, Perplexity: 8.16014
# Epoch [2/3], Step [20200/41412], Loss: 2.1856, Perplexity: 8.89582
# Epoch [2/3], Step [20300/41412], Loss: 2.6312, Perplexity: 13.8907
# Epoch [2/3], Step [20400/41412], Loss: 2.7253, Perplexity: 15.2616
# Epoch [2/3], Step [20500/41412], Loss: 2.1385, Perplexity: 8.48705
# Epoch [2/3], Step [20600/41412], Loss: 2.5462, Perplexity: 12.7588
# Epoch [2/3], Step [20700/41412], Loss: 2.0576, Perplexity: 7.82726
# Epoch [2/3], Step [20800/41412], Loss: 1.9091, Perplexity: 6.74724
# Epoch [2/3], Step [20900/41412], Loss: 2.2748, Perplexity: 9.72599
# Epoch [2/3], Step [21000/41412], Loss: 1.9852, Perplexity: 7.28028
# Epoch [2/3], Step [21100/41412], Loss: 1.6923, Perplexity: 5.43221
# Epoch [2/3], Step [21200/41412], Loss: 1.9123, Perplexity: 6.76874
# Epoch [2/3], Step [21300/41412], Loss: 2.2579, Perplexity: 9.56280
# Epoch [2/3], Step [21400/41412], Loss: 2.4683, Perplexity: 11.8021
# Epoch [2/3], Step [21500/41412], Loss: 3.0653, Perplexity: 21.4410
# Epoch [2/3], Step [21600/41412], Loss: 2.2807, Perplexity: 9.78320
# Epoch [2/3], Step [21700/41412], Loss: 2.6503, Perplexity: 14.1581
# Epoch [2/3], Step [21800/41412], Loss: 2.4118, Perplexity: 11.1545
# Epoch [2/3], Step [21900/41412], Loss: 2.4222, Perplexity: 11.27105
# Epoch [2/3], Step [22000/41412], Loss: 2.1607, Perplexity: 8.67728
# Epoch [2/3], Step [22100/41412], Loss: 3.1111, Perplexity: 22.4460
# Epoch [2/3], Step [22200/41412], Loss: 2.4036, Perplexity: 11.0626
# Epoch [2/3], Step [22300/41412], Loss: 1.9800, Perplexity: 7.24303
# Epoch [2/3], Step [22400/41412], Loss: 2.2072, Perplexity: 9.09025
# Epoch [2/3], Step [22500/41412], Loss: 2.6323, Perplexity: 13.9058
# Epoch [2/3], Step [22600/41412], Loss: 2.1085, Perplexity: 8.23633
# Epoch [2/3], Step [22700/41412], Loss: 2.1777, Perplexity: 8.82617
# Epoch [2/3], Step [22800/41412], Loss: 2.3837, Perplexity: 10.8449
# Epoch [2/3], Step [22900/41412], Loss: 2.2669, Perplexity: 9.64912
# Epoch [2/3], Step [23000/41412], Loss: 2.0318, Perplexity: 7.62752
# Epoch [2/3], Step [23100/41412], Loss: 2.5741, Perplexity: 13.1192
# Epoch [2/3], Step [23200/41412], Loss: 2.3571, Perplexity: 10.5601
# Epoch [2/3], Step [23300/41412], Loss: 2.3105, Perplexity: 10.0791
# Epoch [2/3], Step [23400/41412], Loss: 1.8937, Perplexity: 6.64404
# Epoch [2/3], Step [23500/41412], Loss: 2.1256, Perplexity: 8.37816
# Epoch [2/3], Step [23600/41412], Loss: 2.5285, Perplexity: 12.5342
# Epoch [2/3], Step [23700/41412], Loss: 2.0149, Perplexity: 7.49977
# Epoch [2/3], Step [23800/41412], Loss: 2.0202, Perplexity: 7.53965
# Epoch [2/3], Step [23900/41412], Loss: 2.9340, Perplexity: 18.8032
# Epoch [2/3], Step [24000/41412], Loss: 2.2579, Perplexity: 9.56264
# Epoch [2/3], Step [24100/41412], Loss: 2.5318, Perplexity: 12.5761
# Epoch [2/3], Step [24200/41412], Loss: 2.5489, Perplexity: 12.7929
# Epoch [2/3], Step [24300/41412], Loss: 2.4139, Perplexity: 11.1776
# Epoch [2/3], Step [24400/41412], Loss: 1.9631, Perplexity: 7.12136
# Epoch [2/3], Step [24500/41412], Loss: 1.9064, Perplexity: 6.72914
# Epoch [2/3], Step [24600/41412], Loss: 2.1443, Perplexity: 8.53597
# Epoch [2/3], Step [24700/41412], Loss: 2.1225, Perplexity: 8.35205
# Epoch [2/3], Step [24800/41412], Loss: 2.8184, Perplexity: 16.7500
# Epoch [2/3], Step [24900/41412], Loss: 2.5328, Perplexity: 12.5886
# Epoch [2/3], Step [25000/41412], Loss: 1.9935, Perplexity: 7.34103
# Epoch [2/3], Step [25100/41412], Loss: 2.4380, Perplexity: 11.4502
# Epoch [2/3], Step [25200/41412], Loss: 2.3503, Perplexity: 10.4888
# Epoch [2/3], Step [25300/41412], Loss: 2.6825, Perplexity: 14.6218
# Epoch [2/3], Step [25400/41412], Loss: 2.7567, Perplexity: 15.7475
# Epoch [2/3], Step [25500/41412], Loss: 1.9733, Perplexity: 7.19418
# Epoch [2/3], Step [25600/41412], Loss: 2.0558, Perplexity: 7.81290
# Epoch [2/3], Step [25700/41412], Loss: 2.8700, Perplexity: 17.6370
# Epoch [2/3], Step [25800/41412], Loss: 2.2351, Perplexity: 9.34723
# Epoch [2/3], Step [25900/41412], Loss: 2.9729, Perplexity: 19.5489
# Epoch [2/3], Step [26000/41412], Loss: 2.1256, Perplexity: 8.37837
# Epoch [2/3], Step [26100/41412], Loss: 2.5753, Perplexity: 13.1347
# Epoch [2/3], Step [26200/41412], Loss: 2.6010, Perplexity: 13.4766
# Epoch [2/3], Step [26300/41412], Loss: 3.1306, Perplexity: 22.8866
# Epoch [2/3], Step [26400/41412], Loss: 2.0690, Perplexity: 7.91707
# Epoch [2/3], Step [26500/41412], Loss: 2.4634, Perplexity: 11.7444
# Epoch [2/3], Step [26600/41412], Loss: 2.1119, Perplexity: 8.264197
# Epoch [2/3], Step [26700/41412], Loss: 2.6840, Perplexity: 14.6438
# Epoch [2/3], Step [26800/41412], Loss: 2.8513, Perplexity: 17.3107
# Epoch [2/3], Step [26900/41412], Loss: 2.6170, Perplexity: 13.6949
# Epoch [2/3], Step [27000/41412], Loss: 2.9251, Perplexity: 18.6357
# Epoch [2/3], Step [27100/41412], Loss: 2.1490, Perplexity: 8.576385
# Epoch [2/3], Step [27200/41412], Loss: 2.4658, Perplexity: 11.7726
# Epoch [2/3], Step [27300/41412], Loss: 2.3181, Perplexity: 10.1565
# Epoch [2/3], Step [27400/41412], Loss: 2.9769, Perplexity: 19.6279
# Epoch [2/3], Step [27500/41412], Loss: 1.6914, Perplexity: 5.42706
# Epoch [2/3], Step [27600/41412], Loss: 1.9544, Perplexity: 7.05968
# Epoch [2/3], Step [27700/41412], Loss: 2.0927, Perplexity: 8.10707
# Epoch [2/3], Step [27800/41412], Loss: 2.7282, Perplexity: 15.3059
# Epoch [2/3], Step [27900/41412], Loss: 2.4886, Perplexity: 12.0447
# Epoch [2/3], Step [28000/41412], Loss: 2.6623, Perplexity: 14.3291
# Epoch [2/3], Step [28100/41412], Loss: 2.4215, Perplexity: 11.2633
# Epoch [2/3], Step [28200/41412], Loss: 2.4574, Perplexity: 11.6743
# Epoch [2/3], Step [28300/41412], Loss: 2.3419, Perplexity: 10.4007
# Epoch [2/3], Step [28400/41412], Loss: 2.4523, Perplexity: 11.6154
# Epoch [2/3], Step [28500/41412], Loss: 2.0734, Perplexity: 7.95160
# Epoch [2/3], Step [28600/41412], Loss: 3.0150, Perplexity: 20.3901
# Epoch [2/3], Step [28700/41412], Loss: 2.3378, Perplexity: 10.3584
# Epoch [2/3], Step [28800/41412], Loss: 2.0375, Perplexity: 7.67185
# Epoch [2/3], Step [28852/41412], Loss: 2.7560, Perplexity: 15.7363

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.
